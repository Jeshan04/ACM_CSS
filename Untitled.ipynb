# %%
from skimage import io, compare_ssim
import skimage.measure as measure
# Load the two images
img1 = io.imread("image1.jpg")
img2 = io.imread("image2.jpg")

# Compute the SSIM score
score = compare_ssim(img1, img2, multichannel=True)

# Print the similarity score
print("Similarity score: {:.2f}%".format(score * 100))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18468/1014448910.py in <module>
# ----> 1 from skimage import io, compare_ssim
#       2 import skimage.measure as measure
#       3 # Load the two images
#       4 img1 = io.imread("image1.jpg")
#       5 img2 = io.imread("image2.jpg")
#
# ImportError: cannot import name 'compare_ssim' from 'skimage' (C:\Users\gupta\anaconda3\lib\site-packages\skimage\__init__.py)

# %%
# !pip uninstall scikit-image
# !pip install scikit-image==0.15.0 -U -i https://pypi.tuna.tsinghua.edu.cn/simple

# %%
from skimage import metrics

metrics.structural_similarity(img1, img2, full=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9800/2110153336.py in <module>
#       1 from skimage import metrics
#       2
# ----> 3 metrics.structural_similarity(img1, img2, full=True)
#
# ~\anaconda3\lib\site-packages\skimage\metrics\_structural_similarity.py in structural_similarity(im1, im2, win_size, gradient, data_range, multichannel, gaussian_weights, full, **kwargs)
#     150
#     151     if np.any((np.asarray(im1.shape) - win_size) < 0):
# --> 152         raise ValueError(
#     153             "win_size exceeds image extent.  If the input is a multichannel "
#     154             "(color) image, set multichannel=True.")
#
# ValueError: win_size exceeds image extent.  If the input is a multichannel (color) image, set multichannel=True.

# %%
import tensorflow as tf

# Load the pre-trained CNN model
model = tf.keras.applications.ResNet50(weights='imagenet', include_top=True)

# Load and preprocess the image
img = tf.keras.preprocessing.image.load_img('image1.jpg', target_size=(224, 224))
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.keras.applications.resnet50.preprocess_input(img_array)

# Extract features from the image
features = model.predict(img_array[tf.newaxis, ...])

# Make a prediction
predictions = model.predict(features)

# Get the likelihood score for the predicted class
likelihood_score = predictions[0, tf.argmax(predictions)]

print("Likelihood score: ", likelihood_score)
# Out:
# ...
# 1/1 [==============================] - 2s 2s/step
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9800/1565687590.py in <module>
#      13
#      14 # Make a prediction
# ---> 15 predictions = model.predict(features)
#      16
#      17 # Get the likelihood score for the predicted class
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ...

# %%
from skimage import io
from sewar.full_ref import ssim
img1 = io.imread("image1 (2).jpg")
img2 = io.imread("image1.jpg")
score = ssim(img1, img2)
print(score[0])
# Out:
# 0.9526320681551209

# %%
import timeit
 
# code snippet to be executed only once
mysetup = '''
from skimage import io
from sewar.full_ref import ssim'''
 
# code snippet whose execution time is to be measured
mycode = '''
img1 = io.imread("image1 (2).jpg")
img2 = io.imread("image1.jpg")
score = ssim(img1, img2)
print(score[0])
'''
 
# timeit statement
print (timeit.timeit(setup = mysetup,
                     stmt = mycode,
                     ))
# Out:
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# 0.9526320681551209
# ...
